# %% [markdown]
# <div style="text-align: right">INFO 6105 - Data Science Eng Methods and Tools</div>
# <div style="text-align: right">Assignment 8</div>
#
#
# **Method of Moments (MOM)**
#
# *Team Number: 22*
#
# **--Vignesh Kumar Baskar [002196442]**
#
# **--Shankarsubramaniyan Ganapathi Subramanian [001529711]**

# %% [markdown]
# *In this assignment we have analyzed the **Tornado Dataset for the 36 US States for the past 70 years**.*
#
# *Finally, we have got the respective mean and variance for the respective states and plotted it as a histogram.*
#
# **Steps:**
#
# *1. Loading the data as a dataframe using Pandas*
#
# *2. Plotting the histogram of the loaded dataframe*
#
# *3. Data Cleansing*
#
# *4. Methods of Moments*
#
# *5. Plotting the histogram with Mean and Variance*
#
# *6. Conclusion*

# %% [markdown]
# *Initially, checking the path of the working directory*

# %%
import os
os.getcwd()
# Out:
# 'E:\\DAMG\\Data Science Methods and Techniques\\Assignments\\MOM'

# %% [markdown]
# **Loading the Dataset from the CSV file**

# %%
import pandas as pd

tornado = pd.read_csv("Tornado_Data_Count.csv", index_col=0)
tornado.head()
# Out:
#         ALABAMA  ARIZONA  ARKANSAS  CALIFORNIA  COLORADO  FLORIDA  GEORGIA  \
# States
# 1951          5        0         3           1         8        9        3
# 1952         13        1        29           1         3       10       13
# 1953         22        0        11           2        14       21       12
# 1954         10        2        33           1         9       13       37
# 1955          8        1        28           3        19       12       16
#
#         ILLINOIS  INDIANA  IOWA  ...  OKLAHOMA  PENNSYLVANIA  SOUTH CAROLINA  \
# States                           ...
# 1951           5        5     5  ...        45             4               1
# 1952           4        2     6  ...        25             7               3
# 1953           5        9    32  ...        56             6               4
# 1954           9       32    19  ...        61            22               1
# 1955          27       17     7  ...        77             3               7
#
# ...

# %%
years, states = tornado.shape
print("Total number of years in the dataset:",years)
print("Total number of states in the dataset:", states)
# Out:
# Total number of years in the dataset: 69
# Total number of states in the dataset: 36

# %% [markdown]
# **Plotting the Histogram**

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

tornado.hist(bins=30, figsize=(10, 8))
plt.tight_layout()

# %% [markdown]
# *The plotted histogram of all the states looks like a one humped dataset*

# %% [markdown]
# **Data Cleansing**

# %%
tornado.head()
# Out:
#         ALABAMA  ARIZONA  ARKANSAS  CALIFORNIA  COLORADO  FLORIDA  GEORGIA  \
# States
# 1951          5        0         3           1         8        9        3
# 1952         13        1        29           1         3       10       13
# 1953         22        0        11           2        14       21       12
# 1954         10        2        33           1         9       13       37
# 1955          8        1        28           3        19       12       16
#
#         ILLINOIS  INDIANA  IOWA  ...  OKLAHOMA  PENNSYLVANIA  SOUTH CAROLINA  \
# States                           ...
# 1951           5        5     5  ...        45             4               1
# 1952           4        2     6  ...        25             7               3
# 1953           5        9    32  ...        56             6               4
# 1954           9       32    19  ...        61            22               1
# 1955          27       17     7  ...        77             3               7
#
# ...

# %% [markdown]
# *By analyzing the above dataframe, we could able to see there are many zero values as part of the dataset.*
#
# *Even though there are no occurance of the tornado for a particular, for the purpose of analyzing we are replacing the value of 0's to the  mean values for the respective states.*

# %%
for col in tornado:
    tornado[col] = tornado[col].replace(0, round(tornado[col].mean(),2))

# %%
tornado.head()
# Out:
#         ALABAMA  ARIZONA  ARKANSAS  CALIFORNIA  COLORADO  FLORIDA  GEORGIA  \
# States
# 1951          5     3.87         3         1.0         8        9        3
# 1952         13     1.00        29         1.0         3       10       13
# 1953         22     3.87        11         2.0        14       21       12
# 1954         10     2.00        33         1.0         9       13       37
# 1955          8     1.00        28         3.0        19       12       16
#
#         ILLINOIS  INDIANA  IOWA  ...  OKLAHOMA  PENNSYLVANIA  SOUTH CAROLINA  \
# States                           ...
# 1951           5        5     5  ...        45           4.0               1
# 1952           4        2     6  ...        25           7.0               3
# 1953           5        9    32  ...        56           6.0               4
# 1954           9       32    19  ...        61          22.0               1
# 1955          27       17     7  ...        77           3.0               7
#
# ...

# %% [markdown]
# *Now, we can able to see that the 0's has been replaced with the mean values*

# %% [markdown]
# **Methods of Moments**

# %% [markdown]
# *Calculating the mean values for all the US states:*

# %%
tornado_mean = tornado.mean()
tornado_mean
# Out:
# ALABAMA            37.710145
# ARIZONA             4.206087
# ARKANSAS           32.304348
# CALIFORNIA          6.850870
# COLORADO           31.536232
# FLORIDA            49.550725
# GEORGIA            28.768116
# ILLINOIS           40.724638
# INDIANA            25.608696
# IOWA               42.623188
# KANSAS             67.000000
# KENTUCKY           17.422754
# LOUISIANA          34.072464
# MARYLAND            6.346667
# MASSACHUSETTS       3.154783
# MICHIGAN           17.246377
# MINNESOTA          30.217391
# MISSISSIPPI        39.855072
# MISSOURI           39.347826
# MONTANA             6.362899
# NEBRASKA           44.014493
# NEW MEXICO          9.231014
# NEW YORK            7.053913
# NORTH CAROLINA     21.594203
# NORTH DAKOTA       23.550725
# OHIO               18.716667
# OKLAHOMA           64.028986
# PENNSYLVANIA       13.511884
# SOUTH CAROLINA     15.898551
# SOUTH DAKOTA       26.217391
# TENNESSEE          20.376812
# TEXAS             135.072464
# ...

# %% [markdown]
# *Calculating the variance for all the US states:*

# %%
tornado_var = tornado.var()
tornado_var
# Out:
# ALABAMA           1064.297101
# ARIZONA             10.649571
# ARKANSAS           721.156010
# CALIFORNIA          35.412061
# COLORADO           460.575874
# FLORIDA            687.692242
# GEORGIA            492.268968
# ILLINOIS           886.731884
# INDIANA            284.388747
# IOWA               704.620631
# KANSAS            1553.823529
# KENTUCKY           222.039664
# LOUISIANA          602.656436
# MARYLAND            31.895367
# MASSACHUSETTS        6.181890
# MICHIGAN           102.658994
# MINNESOTA          456.231458
# MISSISSIPPI        897.831628
# MISSOURI           776.083120
# MONTANA             26.175197
# NEBRASKA           536.249787
# NEW MEXICO          37.387050
# NEW YORK            31.056451
# NORTH CAROLINA     312.803495
# NORTH DAKOTA       234.839301
# OHIO               200.202402
# OKLAHOMA          1182.969736
# PENNSYLVANIA       134.338568
# SOUTH CAROLINA     234.386616
# SOUTH DAKOTA       240.554987
# TENNESSEE          361.179454
# ...

# %% [markdown]
# *Using the moments to find the $\alpha$ and $\beta$ for each month:*
#
# **Calculating the $\alpha$:**
#
# $\alpha = \frac{\bar{X}^2}{S^2}$
#
#
# Mean: $\bar{X}$
#
# Variance: $S^2$

# %%
alpha_mom = (tornado_mean)**2/tornado_var
alpha_mom
# Out:
# ALABAMA           1.336145
# ARIZONA           1.661209
# ARKANSAS          1.447081
# CALIFORNIA        1.325379
# COLORADO          2.159327
# FLORIDA           3.570310
# GEORGIA           1.681204
# ILLINOIS          1.870347
# INDIANA           2.306017
# IOWA              2.578318
# KANSAS            2.889002
# KENTUCKY          1.367109
# LOUISIANA         1.926359
# MARYLAND          1.262885
# MASSACHUSETTS     1.609969
# MICHIGAN          2.897335
# MINNESOTA         2.001376
# MISSISSIPPI       1.769181
# MISSOURI          1.994956
# MONTANA           1.546750
# NEBRASKA          3.612637
# NEW MEXICO        2.279175
# NEW YORK          1.602169
# NORTH CAROLINA    1.490743
# NORTH DAKOTA      2.361771
# OHIO              1.749797
# OKLAHOMA          3.465609
# PENNSYLVANIA      1.359036
# SOUTH CAROLINA    1.078406
# SOUTH DAKOTA      2.857358
# TENNESSEE         1.149607
# TEXAS             6.604347
# VIRGINIA          0.678501
# WEST VIRGINIA     1.221963
# ...

# %% [markdown]
# **Calculating the $\beta$:**
#
# $\beta = \frac{S^2}{\bar{X}}$
#
#
# Mean: $\bar{X}$
#
# Variance: $S^2$

# %%
beta_mom = tornado_var/tornado_mean
beta_mom
# Out:
# ALABAMA           28.223098
# ARIZONA            2.531943
# ARKANSAS          22.323807
# CALIFORNIA         5.168988
# COLORADO          14.604658
# FLORIDA           13.878551
# GEORGIA           17.111617
# ILLINOIS          21.773843
# INDIANA           11.105163
# IOWA              16.531392
# KANSAS            23.191396
# KENTUCKY          12.744235
# LOUISIANA         17.687492
# MARYLAND           5.025530
# MASSACHUSETTS      1.959530
# MICHIGAN           5.952496
# MINNESOTA         15.098307
# MISSISSIPPI       22.527412
# MISSOURI          19.723659
# MONTANA            4.113722
# NEBRASKA          12.183482
# NEW MEXICO         4.050156
# NEW YORK           4.402727
# NORTH CAROLINA    14.485531
# NORTH DAKOTA       9.971638
# OHIO              10.696477
# OKLAHOMA          18.475535
# PENNSYLVANIA       9.942253
# SOUTH CAROLINA    14.742640
# SOUTH DAKOTA       9.175398
# TENNESSEE         17.725023
# TEXAS             20.452054
# VIRGINIA          17.963734
# ...

# %% [markdown]
# **Plotting the histogram with Mean and Variance for the respective state**
#
# Using the **gamma.pdf** function in **scipy.stats.distributions** to plot the distributions implied by the calculated alphas and betas.

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from scipy.stats.distributions import gamma

tornado['GEORGIA'].hist(bins=20)  # Checking for the state Georgia
plt.plot(np.linspace(0, 10), gamma.pdf(np.linspace(0, 10), alpha_mom[0], beta_mom[0]))

# %% [markdown]
# Plotting the Histogram for all the states:
#
# *We have increased the size of the histogram (20,10) for better view*

# %%
tornado_states = tornado.hist(figsize=(12, 8), sharex=True, sharey=True, bins=15, grid=True)
tornado_states
# Out:
# array([[<AxesSubplot:title={'center':'ALABAMA'}>,
#         <AxesSubplot:title={'center':'ARIZONA'}>,
#         <AxesSubplot:title={'center':'ARKANSAS'}>,
#         <AxesSubplot:title={'center':'CALIFORNIA'}>,
#         <AxesSubplot:title={'center':'COLORADO'}>,
#         <AxesSubplot:title={'center':'FLORIDA'}>],
#        [<AxesSubplot:title={'center':'GEORGIA'}>,
#         <AxesSubplot:title={'center':'ILLINOIS'}>,
#         <AxesSubplot:title={'center':'INDIANA'}>,
#         <AxesSubplot:title={'center':'IOWA'}>,
#         <AxesSubplot:title={'center':'KANSAS'}>,
#         <AxesSubplot:title={'center':'KENTUCKY'}>],
#        [<AxesSubplot:title={'center':'LOUISIANA'}>,
#         <AxesSubplot:title={'center':'MARYLAND'}>,
#         <AxesSubplot:title={'center':'MASSACHUSETTS'}>,
#         <AxesSubplot:title={'center':'MICHIGAN'}>,
#         <AxesSubplot:title={'center':'MINNESOTA'}>,
#         <AxesSubplot:title={'center':'MISSISSIPPI'}>],
# ...

# %% [markdown]
# Now, adding the **label values** for all the plotted histogram along with their **mean and variance**

# %%
print("US States:\n")
for x in tornado_states.ravel():
    print(x.get_title())
# Out:
# US States:
#
# ALABAMA
# ARIZONA
# ARKANSAS
# CALIFORNIA
# COLORADO
# FLORIDA
# GEORGIA
# ILLINOIS
# INDIANA
# IOWA
# KANSAS
# KENTUCKY
# LOUISIANA
# MARYLAND
# MASSACHUSETTS
# MICHIGAN
# MINNESOTA
# MISSISSIPPI
# MISSOURI
# MONTANA
# NEBRASKA
# NEW MEXICO
# NEW YORK
# NORTH CAROLINA
# NORTH DAKOTA
# OHIO
# OKLAHOMA
# PENNSYLVANIA
# SOUTH CAROLINA
# SOUTH DAKOTA
# TENNESSEE
# TEXAS
# VIRGINIA
# WEST VIRGINIA
# WISCONSIN
# WYOMING

# %%
tornado_states = tornado.hist(figsize=(20, 15), bins=15, grid=True)

for i in tornado_states.ravel():
    
    m = i.get_title()  #Month
    x = np.linspace(*i.get_xlim())  # Plotting fitted distribution
    i.plot(x, gamma.pdf(x, alpha_mom[m], beta_mom[m]))
    
    label = f'alpha = {round(alpha_mom[m],2)}\nbeta = {round(beta_mom[m],2)}'
    i.annotate(label, xy=(10, 3))
    
plt.tight_layout()

# %% [markdown]
# **Conclusion**

# %% [markdown]
# As per the observations from the above plotted histograms,
#
# 1. All the data are positive
# 2. The datas are measuring the tornado for the US states with respect to each year
# 2. All the data are continuous
# 3. The mean values are less than the variance in all the states
# 4. Its evident that tornado is highly influenced by the period of years since due to high variance

# %% [markdown]
# **Thank you!**
